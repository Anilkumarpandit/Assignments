# %%
Answer 1:
    
Yes, there is a difference in the data type of variables list_ and array_list.

The variable list_ is a Python list, while array_list is a NumPy array.

Here's the code to print the data types of both variables:

import numpy as np

list_ = ['1', '2', '3', '4', '5']
array_list = np.array(object=list_)

print("Data type of list_:", type(list_))
print("Data type of array_list:", type(array_list))



Answer 2:
    
import numpy as np

list_ = ['1', '2', '3', '4', '5']
array_list = np.array(object=list_)

print("Data type of elements in list_:")
for item in list_:
    print(type(item))

print("\nData type of elements in array_list:")
for item in array_list:
    print(type(item))

    
    
    
Answer 3:
    

Yes, there will be a difference in the data type of the elements present in both the variables list_ and array_list after the modification you mentioned.

In the modified array_list where you specified dtype=int, the elements will be converted to integers. However, the original list_ contains strings.

Here's the code to print the data types of each element present in both variables list_ and array_list after the modification:

import numpy as np

list_ = ['1', '2', '3', '4', '5']
array_list = np.array(object=list_, dtype=int)

print("Data type of elements in list_:")
for item in list_:
    print(type(item))

print("\nData type of elements in array_list:")
for item in array_list:
    print(type(item))

    
import numpy as np

num_list = [[1, 2, 3], [4, 5, 6]]
num_array = np.array(object=num_list)

print("Data type of elements in num_list:")
for sublist in num_list:
    for item in sublist:
        print(type(item))

print("\nData type of elements in num_array:")
for sublist in num_array:
    for item in sublist:
        print(type(item))

        
  

Answer 4:
    import numpy as np

num_list = [[1, 2, 3], [4, 5, 6]]
num_array = np.array(object=num_list)

# (i) Shape of the array
shape_of_array = num_array.shape
print("Shape of the array:", shape_of_array)

# (ii) Size of the array
size_of_array = num_array.size
print("Size of the array:", size_of_array)




Answer 5:
    
import numpy as np

# Creating a 3x3 matrix of zeros
zeros_matrix = np.zeros((3, 3))

print("Matrix of zeros:")
print(zeros_matrix)




Answer 6:
    
import numpy as np

# Creating an identity matrix of shape (5, 5)
identity_matrix = np.eye(5)

print("Identity matrix:")
print(identity_matrix)
