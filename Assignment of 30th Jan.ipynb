# %%
Answer 1: 
    marks=int(input("Enter Percentage: "))
    if marks>90:
        print("Grade A")
    elif marks>80 and marks<=90:
        print("Grade B")
    elif marks>=60 and marks<=80:
        print("Grade C")
    else:
        print("Grade D")

        
Answer 2:
    cost=int(input("Enter Cost Price (in Rs.): "))
    if cost>100000:
        print("You have to pay 15% Tax")
    elif cost>50000 and cost<=100000:
        print("You have to pay 10% Tax")
    elif cost<=50000:
        print("You have to pay 5% Tax")
        
        
Answer 3:
    city=input("Enter City: ")
    if city=="Delhi" or city=="delhi":
        print("Red Fort")
    elif city=="Agra" or city=="agra":
        print("Taj Mahal")
    elif city=="Jaipur" or city=="jaipur":
        print("Jal mahal")
    else:
        print("Invalid City")
        
        
Answer 4:
    def count_division(number):
        count=0
        while number>10:
            number=number/3
            count+=1
        return count
    print(count_division(30))
    
    
Answer 5:
    Python while loop is used to run a bolck code until a certain condition is met. while loop evaluate the condition.
    If the condition evaluates to True, the code inside the while loop is executed. And when the condition becomes False,
    the line immediately after the loop in the program is executed.
    Example:-
        count=0
        while (count<5):
            count+=1
            print("Hello pwskills")
            
            
Answer 6:
    #Pattern 1
    n=int(input("Enter number of rows: "))
    i=1
    while i<=n:
        j=1
        while j<=i:
            print("*",end=" ")
            j+=1
        print()
        i+=1
        
    #Pattern 2
    n=int(input("Enter number of rows: "))
    i=1
    while i<=n:
        j=n
        while j>=i:
            print("*",end=" ")
            j-=1
        print()
        i+=1
        
    #Pattern 3
    rows=5
    k=2*rows-2
    for i in range(rows,-1,-1):
        for j in range(k,0,-1):
            print(end=" ")
        k=k+1
        for j in range(0,i+1):
            print("*",end=" ")
        print("")
        
        
Answer 7:
    i=10
    while i>0:
        print(i)
        i=i-1
        
        
Answer 8:  
    i=10
    while i>0:
        print(i)
        i=i-1
