# %%
Answer 1:
    For loop is used when the number of iterations is already known. While loop is used when the number of iterations is 
    already Unknown. In the while loop, it can be repeated at every iteration. To iterate, the range or xrange function 
    is used.
    
    #Example of for Loop
    inputList = [10, 20, 30, 40, 50]
    print("Input list elements:")
    for element in inputList:
       print(element)
    
    #Example of while loop
    i = 1
    while i < 10:
       print(i)
       i += 1 
        
        
Answer 2:
    
    #Sum of first 10 Natural Number using while loop
    num = 10
    if num < 0:
       print("Enter a positive number")
    else:
       sum = 0
       while(num > 0):
           sum += num
           num -= 1
       print("The sum is ",sum)
    
    
    #Product of first 10 Natural Number using while loop
    result=1
    count=1
    while count<=10:
        result*=count
        count+=1
    print("The Product is ",result)
    
    
    #Sum of first 10 Natural Number using for loop
    sum=0
    for i in range(1,11):
        sum+=i
    print("The Sum is ",sum)
    
    
    #Product of first 10 Natural Number using for loop
    result=1
    for i in range(1,11):
        result*=i
    print("The Product is ",result)
    
    
Answer 3:
    def calculate_electricity_bill(units):
    total_bill=0
    if units<=100:
        total_bill=units*4.5
    elif units<=200:
        total_bill=100*4.5+(units-100)*6
    elif units<=300:
        total_bill=100*4.5+100*6+(units-200)*10
    else:
        total_bill=100*4.5+100*6+100*10+(units-300)*20
    return total_bill
    
units_consumed=int(input("Enter the Units Consumed: "))
bill_amount=calculate_electricity_bill(units_consumed)
print("The Total Electricity Bill is: ",bill_amount)


Answer 4:
    
    #Using a for loop
    numbers=list(range(1,101))
    result_list=[]
    for num in numbers:
        cube=num**3
        if cube % 4 == 0 or cube % 5 == 0:
            result_list.append(num)
    print("Number whose cube is divisible by 4 or 5: ",result_list)
    
    
    #Using a while loop
    numbers=list(range(1,101))
    result_list=[]
    index=0
    while index < len(numbers):
        cube=numbers[index]**3
        if cube % 4 == 0 or cube % 5 == 0:
            result_list.append(numbers[index])
        index+=1
    print("Number whose cube is divisible by 4 or 5: ",result_list)
    
    
    
Answer 5:
# Out:
#   Cell In[1], line 1
#     Answer 1:
#            ^
# SyntaxError: invalid syntax
