# %%
Answer 1:
    
    def extract_numeric_values(lst):
        numeric_values = []
    
        for item in lst:
            if isinstance(item, (int, float)):
                numeric_values.append(item)
            elif isinstance(item, list) or isinstance(item, tuple):
                numeric_values.extend(extract_numeric_values(item))
            elif isinstance(item, dict):
                for value in item.values():
                    if isinstance(value, (int, float)):
                        numeric_values.append(value)
    
        return numeric_values

    def product_of_numbers(lst):
        flat_numeric_values = extract_numeric_values(lst)
        product = 1
    
        for num in flat_numeric_values:
            product *= num
    
        return product

    list1 = [1, 2, 3, 4, [44, 55, 66, True], False, (34, 56, 78, 89, 34), {1, 2, 3, 3, 2, 1}, {1: 34, "key2": [55, 67, 78, 89], 4: (45, 22, 61, 34)}, [56, 'data science'], 'Machine Learning']

    result = product_of_numbers(list1)
    print(result)
    
    
    
Answer 2:
    
    def encrypt_message(message):
        encrypted_message = ""
        for char in message:
            if char.isalpha():
                if char.islower():
                    encrypted_char = chr(122 - (ord(char) - 97))  # Convert to lowercase ASCII values (a=97, z=122)
                else:
                    encrypted_char = chr(90 - (ord(char) - 65))   # Convert to uppercase ASCII values (A=65, Z=90)
            elif char == ' ':
                encrypted_char = '$'
            else:
                encrypted_char = char
            encrypted_message += encrypted_char
        return encrypted_message

    input_sentence = "I want to become a Data Scientist."
    lowercase_input = input_sentence.lower()  # Convert to lowercase

    encrypted_result = encrypt_message(lowercase_input)
print(encrypted_result)
